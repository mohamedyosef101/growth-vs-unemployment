# %% [markdown]
# <img src="https://fred.stlouisfed.org/images/fred-masthead-mobile-2x.png">
#
# # Economic Data Analysis with Fred
# Fred is an economic data website which include a varity of data sources; it's all time series data, financial, and economic data. Beside, they have their own API so there is no need to scrap the website or download csv.
#
#
# **For now**, I don't know what I going to do yet, but I'm exploring the abilities of Fred and its data.
#
# <br>

# %%
# import the essential python libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Step 0: Set the API
# To get my api key, I need to go to [Rred API Keys](https://fred.stlouisfed.org/docs/api/api_key.html) and request an API Key.
#
# And to request this key, I need to:
# 1. Register a Fred account using my Google one.
# 2. Enter a simple message explaining what I'm going to do with the API Key.
# 3. Finally, accept the Fred rules.
#
# <br>

# %% [markdown]
# **NOTE** if you're following along, you'll need to download fredapi first. And to do that use this:
#
# ```python
# !pip install fredapi
# ```

# %%
# import the API key
from fredapi import Fred

# I've made mine as a secret but for you uncomment this
#fred_key = 'put your key here' 

# and let's get my secret api key
from config import fred_api

# %% [markdown]
# If you want to make you API as secret too, [read this](https://www.kaggle.com/discussions/general/441975)

# %% [markdown]
# # Step 1: Pull the data

# %%
# Create fred object
fred = Fred(api_key=fred_api)

# %%
fred.search("S&P")
# Out:
#                                 id realtime_start realtime_end  \
# series id
# SP500                        SP500     2023-09-20   2023-09-20
# VXVCLS                      VXVCLS     2023-09-20   2023-09-20
# CSUSHPINSA              CSUSHPINSA     2023-09-20   2023-09-20
# CSUSHPISA                CSUSHPISA     2023-09-20   2023-09-20
# VXOCLS                      VXOCLS     2023-09-20   2023-09-20
# ...                            ...            ...          ...
# CSHICPTZA156NRUG  CSHICPTZA156NRUG     2023-09-20   2023-09-20
# CSHRCPIQA156NRUG  CSHRCPIQA156NRUG     2023-09-20   2023-09-20
# CSHRCPCNA156NRUG  CSHRCPCNA156NRUG     2023-09-20   2023-09-20
# CSHCCPLAA156NRUG  CSHCCPLAA156NRUG     2023-09-20   2023-09-20
# CSHRCPCHA156NRUG  CSHRCPCHA156NRUG     2023-09-20   2023-09-20
#
#                                                               title  \
# series id
# SP500                                                       S&P 500
# VXVCLS                        CBOE S&P 500 3-Month Volatility Index
# CSUSHPINSA          S&P/Case-Shiller U.S. National Home Price Index
# CSUSHPISA           S&P/Case-Shiller U.S. National Home Price Index
# VXOCLS            CBOE S&P 100 Volatility Index: VXO (DISCONTINUED)
# ...                                                             ...
# CSHICPTZA156NRUG  Share of Gross Capital Formation at Current Pu...
# CSHRCPIQA156NRUG  Share of Residual Trade and GDP Statistical Di...
# CSHRCPCNA156NRUG  Share of Residual Trade and GDP Statistical Di...
# CSHCCPLAA156NRUG  Share of Household Consumption at Current Purc...
# CSHRCPCHA156NRUG  Share of Residual Trade and GDP Statistical Di...
#
#                  observation_start observation_end     frequency  \
# series id
# SP500                   2013-09-20      2023-09-19  Daily, Close
# VXVCLS                  2007-12-04      2023-09-19  Daily, Close
# CSUSHPINSA              1987-01-01      2023-06-01       Monthly
# CSUSHPISA               1987-01-01      2023-06-01       Monthly
# VXOCLS                  1986-01-02      2021-09-23  Daily, Close
# ...                            ...             ...           ...
# CSHICPTZA156NRUG        1960-01-01      2019-01-01        Annual
# CSHRCPIQA156NRUG        1970-01-01      2019-01-01        Annual
# CSHRCPCNA156NRUG        1952-01-01      2019-01-01        Annual
# CSHCCPLAA156NRUG        1970-01-01      2019-01-01        Annual
# CSHRCPCHA156NRUG        1950-01-01      2019-01-01        Annual
#
#                  frequency_short               units         units_short  \
# series id
# SP500                          D               Index               Index
# VXVCLS                         D               Index               Index
# CSUSHPINSA                     M  Index Jan 2000=100  Index Jan 2000=100
# CSUSHPISA                      M  Index Jan 2000=100  Index Jan 2000=100
# VXOCLS                         D               Index               Index
# ...                          ...                 ...                 ...
# CSHICPTZA156NRUG               A             Percent                   %
# CSHRCPIQA156NRUG               A             Percent                   %
# CSHRCPCNA156NRUG               A             Percent                   %
# CSHCCPLAA156NRUG               A             Percent                   %
# CSHRCPCHA156NRUG               A             Percent                   %
#
#                       seasonal_adjustment seasonal_adjustment_short  \
# series id
# SP500             Not Seasonally Adjusted                       NSA
# VXVCLS            Not Seasonally Adjusted                       NSA
# CSUSHPINSA        Not Seasonally Adjusted                       NSA
# CSUSHPISA             Seasonally Adjusted                        SA
# VXOCLS            Not Seasonally Adjusted                       NSA
# ...                                   ...                       ...
# CSHICPTZA156NRUG  Not Seasonally Adjusted                       NSA
# CSHRCPIQA156NRUG  Not Seasonally Adjusted                       NSA
# CSHRCPCNA156NRUG  Not Seasonally Adjusted                       NSA
# CSHCCPLAA156NRUG  Not Seasonally Adjusted                       NSA
# CSHRCPCHA156NRUG  Not Seasonally Adjusted                       NSA
#
#                                last_updated popularity  \
# series id
# SP500             2023-09-19 19:13:31-05:00         82
# VXVCLS            2023-09-20 08:36:09-05:00         53
# CSUSHPINSA        2023-08-29 08:11:02-05:00         90
# CSUSHPISA         2023-08-29 08:11:04-05:00         80
# VXOCLS            2021-09-24 08:36:03-05:00         29
# ...                                     ...        ...
# CSHICPTZA156NRUG  2021-11-08 13:32:32-06:00          3
# CSHRCPIQA156NRUG  2021-11-08 13:35:11-06:00          3
# CSHRCPCNA156NRUG  2021-11-08 13:35:26-06:00          3
# CSHCCPLAA156NRUG  2021-11-08 13:32:56-06:00          3
# CSHRCPCHA156NRUG  2021-11-08 13:35:27-06:00          3
#
#                                                               notes
# series id
# SP500             The observations for the S&P 500 represent the...
# VXVCLS            Copyright, 2016, Chicago Board Options Exchang...
# CSUSHPINSA        For more information regarding the index, plea...
# CSUSHPISA         For more information regarding the index, plea...
# VXOCLS            This series is no longer being updated by the ...
# ...                                                             ...
# CSHICPTZA156NRUG  Source ID: csh_i  When using these data in you...
# CSHRCPIQA156NRUG  Source ID: csh_r  When using these data in you...
# CSHRCPCNA156NRUG  Source ID: csh_r  When using these data in you...
# CSHCCPLAA156NRUG  Source ID: csh_c  When using these data in you...
# CSHRCPCHA156NRUG  Source ID: csh_r  When using these data in you...
#
# [1000 rows x 15 columns]

# %% [markdown]
# <hr>
#
# # Acknowledgement
# (1) The first inspiration to even work with Fred API was [Rob Mulla YouTube video about Economic Data Analysis](https://youtu.be/R67XuYc9NQ4?si=UCZzfiG8xd9IGv8A)
