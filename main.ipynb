# %% [markdown]
# <img src="https://fred.stlouisfed.org/images/fred-masthead-mobile-2x.png">
#
# # Economic Data Analysis with Fred
# Fred is an economic data website which include a varity of data sources; it's all time series data, financial, and economic data. Beside, they have their own API so there is no need to scrap the website or download csv.
#
#
# **For now**, I don't know what I going to do yet, but I'm exploring the abilities of Fred and its data.
#
# <br>

# %%
# import the essential python libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Step 0: Set the API
# To get my api key, I need to go to [Rred API Keys](https://fred.stlouisfed.org/docs/api/api_key.html) and request an API Key.
#
# And to request this key, I need to:
# 1. Register a Fred account using my Google one.
# 2. Enter a simple message explaining what I'm going to do with the API Key.
# 3. Finally, accept the Fred rules.
#
# <br>

# %% [markdown]
# **NOTE** if you're following along, you'll need to download fredapi first. And to do that use this:
#
# ```python
# !pip install fredapi
# ```

# %%
# import the API key
from fredapi import Fred

# I've made mine api key as a secret config variable
# but for you but your api key here
fred_key = 'put your key here' 

# but me I gonna get my secret api key
from config import fred_api

# %% [markdown]
# If you want to make you API as secret too, [read this](https://www.kaggle.com/discussions/general/441975)

# %% [markdown]
# # Step 1: Pull the data

# %%
# Create fred object
fred = Fred(api_key=fred_api)

# %%
fred.search("S&P", limit=10)
# Out:
#                             id realtime_start realtime_end  \
# series id
# SP500                    SP500     2023-09-20   2023-09-20
# VXVCLS                  VXVCLS     2023-09-20   2023-09-20
# CSUSHPINSA          CSUSHPINSA     2023-09-20   2023-09-20
# CSUSHPISA            CSUSHPISA     2023-09-20   2023-09-20
# VXOCLS                  VXOCLS     2023-09-20   2023-09-20
# BAMLH0A0HYM2      BAMLH0A0HYM2     2023-09-20   2023-09-20
# BKTPAAA641N        BKTPAAA641N     2023-09-20   2023-09-20
# DJIA                      DJIA     2023-09-20   2023-09-20
# BAMLH0A0HYM2EY  BAMLH0A0HYM2EY     2023-09-20   2023-09-20
# SPCS20RSA            SPCS20RSA     2023-09-20   2023-09-20
#
#                                                             title  \
# series id
# SP500                                                     S&P 500
# VXVCLS                      CBOE S&P 500 3-Month Volatility Index
# CSUSHPINSA        S&P/Case-Shiller U.S. National Home Price Index
# CSUSHPISA         S&P/Case-Shiller U.S. National Home Price Index
# VXOCLS          CBOE S&P 100 Volatility Index: VXO (DISCONTINUED)
# BAMLH0A0HYM2    ICE BofA US High Yield Index Option-Adjusted S...
# BKTPAAA641N     Failures and Assistance Transactions of all In...
# DJIA                                 Dow Jones Industrial Average
# BAMLH0A0HYM2EY       ICE BofA US High Yield Index Effective Yield
# SPCS20RSA       S&P/Case-Shiller 20-City Composite Home Price ...
#
#                observation_start observation_end     frequency  \
# series id
# SP500                 2013-09-20      2023-09-19  Daily, Close
# VXVCLS                2007-12-04      2023-09-19  Daily, Close
# CSUSHPINSA            1987-01-01      2023-06-01       Monthly
# CSUSHPISA             1987-01-01      2023-06-01       Monthly
# VXOCLS                1986-01-02      2021-09-23  Daily, Close
# BAMLH0A0HYM2          1996-12-31      2023-09-19  Daily, Close
# BKTPAAA641N           1934-01-01      2023-01-01        Annual
# DJIA                  2013-09-20      2023-09-19  Daily, Close
# BAMLH0A0HYM2EY        1996-12-31      2023-09-19  Daily, Close
# SPCS20RSA             2000-01-01      2023-06-01       Monthly
#
#                frequency_short                   units  \
# series id
# SP500                        D                   Index
# VXVCLS                       D                   Index
# CSUSHPINSA                   M      Index Jan 2000=100
# CSUSHPISA                    M      Index Jan 2000=100
# VXOCLS                       D                   Index
# BAMLH0A0HYM2                 D                 Percent
# BKTPAAA641N                  A  Number of Institutions
# DJIA                         D                   Index
# BAMLH0A0HYM2EY               D                 Percent
# SPCS20RSA                    M      Index Jan 2000=100
#
#                            units_short      seasonal_adjustment  \
# series id
# SP500                            Index  Not Seasonally Adjusted
# VXVCLS                           Index  Not Seasonally Adjusted
# CSUSHPINSA          Index Jan 2000=100  Not Seasonally Adjusted
# CSUSHPISA           Index Jan 2000=100      Seasonally Adjusted
# VXOCLS                           Index  Not Seasonally Adjusted
# BAMLH0A0HYM2                         %  Not Seasonally Adjusted
# BKTPAAA641N     Number of Institutions  Not Seasonally Adjusted
# DJIA                             Index  Not Seasonally Adjusted
# BAMLH0A0HYM2EY                       %  Not Seasonally Adjusted
# SPCS20RSA           Index Jan 2000=100      Seasonally Adjusted
#
#                seasonal_adjustment_short               last_updated  \
# series id
# SP500                                NSA  2023-09-19 19:13:31-05:00
# VXVCLS                               NSA  2023-09-20 08:36:09-05:00
# CSUSHPINSA                           NSA  2023-08-29 08:11:02-05:00
# CSUSHPISA                             SA  2023-08-29 08:11:04-05:00
# VXOCLS                               NSA  2021-09-24 08:36:03-05:00
# BAMLH0A0HYM2                         NSA  2023-09-20 08:42:08-05:00
# BKTPAAA641N                          NSA  2023-05-24 16:01:22-05:00
# DJIA                                 NSA  2023-09-19 19:25:07-05:00
# BAMLH0A0HYM2EY                       NSA  2023-09-20 08:42:11-05:00
# SPCS20RSA                             SA  2023-08-29 08:11:06-05:00
#
#                popularity                                              notes
# series id
# SP500                  82  The observations for the S&P 500 represent the...
# VXVCLS                 53  Copyright, 2016, Chicago Board Options Exchang...
# CSUSHPINSA             90  For more information regarding the index, plea...
# CSUSHPISA              80  For more information regarding the index, plea...
# VXOCLS                 29  This series is no longer being updated by the ...
# BAMLH0A0HYM2           93  The ICE BofA Option-Adjusted Spreads (OASs) ar...
# BKTPAAA641N             2  Transaction Types Institutions have been resol...
# DJIA                   73  The observations for the Dow Jones Industrial ...
# BAMLH0A0HYM2EY         83  This data represents the effective yield of th...
# SPCS20RSA              67  For more information regarding the index, plea...

# %% [markdown]
# <hr>
#
# # Acknowledgement
# (1) The first inspiration to even work with Fred API was [Rob Mulla YouTube video about Economic Data Analysis](https://youtu.be/R67XuYc9NQ4?si=UCZzfiG8xd9IGv8A)
